# %%
#lancer la communication asynchrone avec thymio
from tdmclient import ClientAsync, aw
client = ClientAsync()
node = await client.wait_for_node()
await node.lock()
# Out:
# ---------------------------------------------------------------------------
# NodeLockError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25556/2688140818.py in <module>
#       3 client = ClientAsync()
#       4 node = await client.wait_for_node()
# ----> 5 await node.lock()
#
# ~\anaconda3\lib\site-packages\tdmclient\clientasyncnode.py in lock(self)
#      59         result = yield from self.lock_node()
#      60         if result is not None:
# ---> 61             raise NodeLockError(self.status)
#      62         return self
#      63
#
# NodeLockError: Node lock error (current status: busy)

# %%
# Premade libraries
import cv2
import time
import math
import numpy as np
from matplotlib import pyplot as plt
from shapely.geometry import Polygon, Point, LineString

# Homemade functions
import Vision.vision as vs
import robot as rbt
import Global_Navigation.global_navigation as glb
import Motion_Control.thymio_control as ctrl

# %%
def get_angle2goal(geometry, goal):
    """

    Compute the angle between thecurent orientation of the tymio and its next goal
    :return: beta the angle btw goal/crt orientation
    """
    beta = math.atan2(goal[1] - geometry[0][1], goal[0] - geometry[0][0])
    if beta - geometry[1] < -np.pi:
        beta = -(beta - geometry[1] + np.pi)
    elif beta - geometry[1] > np.pi:
        beta = -(beta - geometry[1] - np.pi)
    else:
        beta = beta - geometry[1]
    return beta

def get_correct_orientation(beta, node, speed, tol):
    if abs(beta) < tol:
        #print("right angle")
        #ctrl.stop_motors(node)
        return(True)
    if beta < 0 :
        ctrl.set_motor_speed(-speed, speed, node)
        return(False)
    elif beta > 0:
        
        ctrl.set_motor_speed(speed, -speed, node)
        return(False)
    
def test_sensors(node,client, tolerance):
    sensor = ctrl.get_prox_sensors(node,client)
    for i in range(5):
        if sensor[i] > tolerance:
             return False 
    return True
    
def get_distance(pos, goal, tol, speed, node):
    dist = np.linalg.norm((goal[0]-pos[0], goal[1]-pos[1]))
    if dist < tol:
        ctrl.stop_motors(node)
        return True
    else:
        spLeft = speed
        spRight = speed
        for i in range(5):
            a = 4-i
            sensor = ctrl.get_prox_sensors(node,client)
            spLeft += sensor[i] * obstSpeedGain[i] // 100
            spRight += sensor[i] * obstSpeedGain[a]//100
        ctrl.set_motor_speed(spRight, spLeft, node)
        if(test_sensors(node, client, 3000)):
            ctrl.set_motor_speed(speed, speed, node)
            #aw(client.sleep(0.5))
        return False

# %%
cap = cv2.VideoCapture(0)
img = vs.get_image(cap)
margin = 10
speedGain = 2     # gain used with ground gradient
obstSpeedGain = np.array([6,4,-2,-6,-8])
thymio = rbt.RobotNav()

# %%
i = 0 #step vis graph
path = 0
while cap.isOpened():
    ret, frame = cap.read()
    
    if thymio.get_state() == 0:
        thymio.initialisation_step(frame, margin, False)
        thymio.set_state(1)
        path = thymio.get_path('real')
        print("fin state")
    
    if thymio.get_state() == 1:  #motion control commence
        pos_thy, two_centres, test_detect = vs.detect_start1(frame, False)  #recupere pos thymio, #test_detect bool a false si thymio pas detetc
        frame = glb.draw_path(frame, thymio.get_path('real')) #dessine chemin du thymio new fenetre
        path_img = thymio.get_path('img')
        if test_detect:
            frame = glb.draw_thymio(frame, path_img)   # dessine point thymio new fenetre
        #frame = glb.draw_thymio(frame, path_kalman)   # dessine point thymio new fenetre
        if test_detect:
            thymio.update_position_cam(two_centres)  #update pos thymio et angle dans la classe robot
        """
        else:
            thymio.update_position_kalman()
        """
        if len(path) > (i+1):
            next_goal = (path[i+1].x,path[i+1].y) 
            angle = get_angle2goal(thymio.get_geometry(), next_goal)  #angle entre thymio et point
            get_correct_orientation(angle, node, 50, 0.2)
            if get_correct_orientation(angle, node, 50, 0.2):
                print("avance")
                get_distance(thymio.get_geometry()[0], next_goal, 30, 200, node)
                if get_distance(thymio.get_geometry()[0], next_goal, 30, 200, node):
                    i = i + 1
                    if i == (len(path)-1):
                        thymio.set_state(2)
                        ctrl.stop_motors(node)
                        print("arrivee")
                        print(thymio.get_state())
                        break      
        
    cv2.imshow('frame',frame)     
    if cv2.waitKey(1) == ord('q'):
        ctrl.stop_motors(node)
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# [[[208.5 306.5  30.2]
#   [226.5 260.5  14.7]]]
# ok
# 0it [00:00, ?it/s]
# [Point(217.00, 283.00), Point(338.00, 86.00)]
# fin state
# [[[208.5 306.5  30.2]
#   [226.5 260.5  14.7]]]
# ok
# (208, 306)
# (226, 260)
# [[[207.5 306.5  30.4]
#   [228.5 261.5  14.7]]]
# ok
# (208, 306)
# (228, 262)
# [[[209.5 306.5  31.6]
#   [234.5 262.5  16.9]]]
# ok
# (210, 306)
# (234, 262)
# [[[205.5 306.5  31.5]
#   [237.5 263.5  13.8]]]
# ok
# (206, 306)
# (238, 264)
# avance
# [[[234.5 281.5  31. ]
#   [273.5 248.5  13.4]]]
# ok
# (234, 282)
# (274, 248)
# [[[245.5 272.5  31.4]
#   [283.5 238.5  16.9]]]
# ok
# (246, 272)
# (284, 238)
# [[[246.5 272.5  31.8]
#   [281.5 237.5  18. ]]]
# ok
# (246, 272)
# (282, 238)
# [[[248.5 269.5  28.8]
#   [279.5 234.5  14.7]]]
# ok
# (248, 270)
# (280, 234)
# [[[247.5 269.5  28.9]
#   [275.5 232.5  18.3]]]
# ok
# (248, 270)
# (276, 232)
# [[[246.5 271.5  29.4]
#   [273.5 226.5  14.9]]]
# ok
# (246, 272)
# (274, 226)
# avance
# [[[259.5 233.5  27.2]
#   [272.5 188.5  14.5]]]
# ok
# (260, 234)
# (272, 188)
# [[[266.5 225.5  27.1]
#   [271.5 180.5  14.5]]]
# ok
# (266, 226)
# (272, 180)
# [[[261.5 225.5  27.2]
#   [276.5 182.5  17.9]]]
# ok
# (262, 226)
# (276, 182)
# [[[259.5 224.5  29.4]
#   [282.5 181.5  16.7]]]
# ok
# (260, 224)
# (282, 182)
# [[[261.5 220.5  27.9]
#   [285.5 182.5  12.5]]]
# ok
# (262, 220)
# (286, 182)
# avance
# [[[282.5 196.5  28.1]
#   [317.5 164.5  14.7]]]
# ok
# (282, 196)
# (318, 164)
# [[[293.5 189.5  27.9]
#   [323.5 157.5  14.5]]]
# ok
# (294, 190)
# (324, 158)
# [[[290.5 188.5  27.9]
#   [322.5 154.5  13.6]]]
# ok
# (290, 188)
# (322, 154)
# [[[290.5 188.5  28. ]]]
# revoir hough circles para
# [[[291.5 187.5  27.2]
#   [312.5 148.5  14.1]]]
# ok
# (292, 188)
# (312, 148)
# avance
# [[[303.5 154.5  25.7]
#   [315.5 117.5  14.5]]]
# ok
# (304, 154)
# (316, 118)
# [[[304.5 141.5  28. ]
#   [317.5 106.5  15.1]]]
# ok
# (304, 142)
# (318, 106)
# [[[302.5 144.5  26.1]
#   [321.5 106.5  15. ]]]
# ok
# (302, 144)
# (322, 106)
# [[[304.5 150.5  29.4]
#   [325.5 107.5  13.8]]]
# ok
# (304, 150)
# (326, 108)
# [[[305.5 140.5  26. ]
#   [330.5 109.5  13.6]]]
# ok
# (306, 140)
# (330, 110)
# [[[305.5 141.5  24.9]
#   [330.5 111.5  15.4]]]
# ok
# (306, 142)
# (330, 112)
# [[[310.5 144.5  23.9]]]
# revoir hough circles para
# [[[302.5 145.5  28.3]
#   [323.5 108.5  14.1]]]
# ok
# (302, 146)
# (324, 108)
# [[[306.5 140.5  25.7]
#   [323.5 108.5  16.8]]]
# ok
# (306, 140)
# (324, 108)
# [[[307.5 138.5  27.9]
#   [326.5 107.5  14.7]]]
# ok
# (308, 138)
# (326, 108)
# avance
# [[[323.5 121.5  28.3]]]
# revoir hough circles para
# avance
# [[[363.5  72.5  42.7]
#   [352.5  95.5  44.9]]]
# ok
# (352, 96)
# (364, 72)
# [[[364.5  68.5  45. ]]]
# revoir hough circles para
# [[[365.5  68.5  46.1]]]
# revoir hough circles para
# [[[368.5  73.5  23.5]]]
# revoir hough circles para
# [[[369.5  74.5  22.4]]]
# revoir hough circles para
# [[[370.5  71.5  23.5]]]
# revoir hough circles para
# [[[369.5  74.5  23.6]]]
# revoir hough circles para
# [[[374.5  74.5  22.5]]]
# revoir hough circles para
# [[[371.5  76.5  26.8]]]
# revoir hough circles para
# [[[376.5  77.5  34.6]]]
# revoir hough circles para
# [[[363.5  66.5  45. ]]]
# revoir hough circles para
# [[[360.5  64.5  46.1]
#   [382.5  79.5  28. ]]]
# ok
# (360, 64)
# (382, 80)

# %%
ctrl.stop_motors(node)

# %%
def avoidance(node, client):
    sensor = ctrl.get_prox_sensors(node,client)

# %%
cap.release()
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(1)
img = vs.get_image(cap)
margin = 10
speedGain = 2     # gain used with ground gradient
obstSpeedGain = np.array([6,4,-2,-6,-8])


data = vs.transmit_data(img, True, margin)
print(data)
#img = cv2.circle(img, (int(path[i][0]), int(path[i][1])), int(3), (0, 0, 255), 2)

cv2.imshow('frame',img)  
cap.release()
# Out:
# [[[164.5 172.5  36.6]
#   [230.5 224.5  18.2]]]
# ok
# ((197.0, 198.0), (535.0, 264.0), [[array([648.0805, 299.008 ], dtype=float32), array([598.59174, 397.23392], dtype=float32), array([622.26984, 348.82208], dtype=float32), array([631.1923 , 327.89932], dtype=float32)], [array([  3.2706385, 215.22668  ], dtype=float32), array([ 18.30791, 336.41025], dtype=float32), array([  1.9690068, 446.89935  ], dtype=float32), array([  1.0276295, 347.14984  ], dtype=float32)], [array([379.49417, 143.66446], dtype=float32), array([395.41476, 146.81915], dtype=float32), array([411.56488, 145.9689 ], dtype=float32), array([429.7781 , 143.16815], dtype=float32), array([428.57886, 151.62352], dtype=float32), array([430.60236, 183.49132], dtype=float32), array([429.17816, 247.50604], dtype=float32), array([433.58926, 283.71942], dtype=float32), array([424.24524, 274.32874], dtype=float32), array([436.4668 , 293.27103], dtype=float32), array([404.86624, 281.9823 ], dtype=float32), array([391.49432, 284.59064], dtype=float32), array([379.69073, 280.72028], dtype=float32), array([367.3956 , 282.68958], dtype=float32), array([355.7531 , 282.99588], dtype=float32), array([364.60208, 276.23376], dtype=float32), array([345.75427, 288.48715], dtype=float32), array([357.11517, 258.90927], dtype=float32), array([353.89526, 246.46683], dtype=float32), array([360.32535, 228.88065], dtype=float32), array([356.2314 , 218.36746], dtype=float32), array([359.82718, 199.58641], dtype=float32), array([359.4827 , 183.48108], dtype=float32), array([361.9438 , 167.54471], dtype=float32), array([356.81964, 153.90889], dtype=float32), array([361.03665, 140.34192], dtype=float32)], [array([93.333466, -8.393414], dtype=float32), array([83.502   ,  8.818936], dtype=float32), array([58.374035, 23.534983], dtype=float32)]], (480, 640, 3), ((230, 224), (164, 172)))

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    ctrl.set_motor_speed(50, 50, node)
    center = vs.detect_start1(frame, False)
    if center[2]:
        frame = cv2.circle(frame, (int(center[0][0]), int(center[0][1])), int(3), (0, 0, 255), 2)
    
    cv2.imshow('frame',frame)     
    if cv2.waitKey(1) == ord('q'):
        ctrl.stop_motors(node)
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# [[[214.5 240.5  28.9]
#   [243.5 200.5  15.6]]]
# ok
# [[[214.5 237.5  29.2]
#   [244.5 197.5  16.9]]]
# ok
# [[[217.5 234.5  27.9]
#   [245.5 195.5  16.9]]]
# ok
# [[[220.5 236.5  27.8]
#   [245.5 193.5  13. ]]]
# ok
# [[[221.5 230.5  27.8]
#   [247.5 191.5  12.5]]]
# ok
# [[[221.5 230.5  29.4]
#   [249.5 190.5  16.6]]]
# ok
# [[[223.5 227.5  29.3]
#   [251.5 189.5  14.1]]]
# ok
# [[[223.5 226.5  29.3]
#   [252.5 185.5  15.8]]]
# ok
# [[[226.5 221.5  31.5]
#   [254.5 183.5  15.5]]]
# ok
# [[[225.5 222.5  29.3]
#   [253.5 182.5  16. ]]]
# ok
# [[[231.5 218.5  29.4]
#   [256.5 179.5  16.1]]]
# ok
# [[[229.5 217.5  29.1]
#   [256.5 177.5  16.7]]]
# ok
# [[[229.5 215.5  29.3]
#   [260.5 176.5  14.4]]]
# ok
# [[[235.5 214.5  29.3]
#   [259.5 175.5  17.6]]]
# ok
# [[[234.5 213.5  27.1]
#   [259.5 173.5  16.6]]]
# ok
# [[[234.5 208.5  28.2]
#   [263.5 169.5  15.8]]]
# ok
# [[[235.5 208.5  29.3]
#   [266.5 168.5  14.5]]]
# ok
# [[[240.5 205.5  29.4]
#   [263.5 165.5  15. ]]]
# ok
# [[[239.5 202.5  28.2]
#   [265.5 165.5  13.6]]]
# ok
# [[[241.5 203.5  27.2]
#   [267.5 164.5  17.4]]]
# ok
# [[[241.5 199.5  29.3]
#   [269.5 162.5  18. ]]]
# ok
# [[[241.5 197.5  28. ]
#   [271.5 159.5  14.9]]]
# ok
# [[[245.5 197.5  27.1]
#   [269.5 155.5  14.9]]]
# ok
# [[[245.5 193.5  29.3]
#   [272.5 155.5  17.1]]]
# ok
# [[[247.5 189.5  28.2]
#   [275.5 152.5  14.7]]]
# ok
# [[[249.5 191.5  26.8]
#   [274.5 152.5  16.6]]]
# ok
# [[[250.5 192.5  29.4]
#   [278.5 149.5  14.7]]]
# ok
# [[[255.5 184.5  27.2]
#   [277.5 148.5  12.5]]]
# ok
# [[[252.5 182.5  27.2]
#   [281.5 145.5  14.5]]]
# ok
# [[[254.5 185.5  28. ]
#   [282.5 144.5  13.8]]]
# ok
# [[[256.5 181.5  27.2]
#   [284.5 141.5  14.5]]]
# ok
# [[[255.5 177.5  28. ]
#   [282.5 141.5  16.9]]]
# ok
# [[[257.5 177.5  29.4]
#   [283.5 139.5  12.5]]]
# ok
# [[[257.5 174.5  28. ]
#   [287.5 137.5  13.6]]]
# ok
# [[[260.5 170.5  25.4]
#   [285.5 136.5  16.9]]]
# ok
# [[[262.5 167.5  27.2]
#   [288.5 133.5  14.4]]]
# ok
# [[[265.5 167.5  28.2]
#   [287.5 133.5  12.5]]]
# ok
# [[[267.5 166.5  23.6]
#   [291.5 129.5  14.4]]]
# ok
# [[[265.5 169.5  28. ]
#   [290.5 129.5  12.5]]]
# ok
# [[[266.5 164.5  25.8]
#   [294.5 126.5  13.8]]]
# ok
# [[[266.5 168.5  33.8]
#   [292.5 124.5  11.8]]]
# ok
# [[[273.5 160.5  25.7]
#   [293.5 125.5  12.7]]]
# ok
# [[[267.5 159.5  28. ]
#   [294.5 122.5  12.5]]]
# ok
# [[[270.5 161.5  31.5]
#   [293.5 119.5  14.1]]]
# ok
# [[[271.5 159.5  27.1]
#   [298.5 119.5  14.4]]]
# ok
# [[[271.5 154.5  27.9]
#   [299.5 118.5  14.1]]]
# ok
# [[[277.5 151.5  27.1]
#   [296.5 115.5  14.1]]]
# ok
# [[[279.5 148.5  27.1]
#   [302.5 114.5  13.2]]]
# ok
# [[[274.5 150.5  28. ]
#   [300.5 113.5  16.3]]]
# ok
# [[[278.5 137.5  49.4]
#   [299.5 110.5  13.8]]]
# ok
# [[[276.5 147.5  28.2]
#   [304.5 110.5  14.6]]]
# ok
# [[[281.5 145.5  27.2]
#   [303.5 108.5  15.2]]]
# ok

# %%
A = (10, 15)
B = (23, 45)
A = np.array(A)
B = np.array(B)

C = (A+B)/2
print(C)
# Out:
# [16.5 30. ]

# %%
margin = 70
speedGain = 2     # gain used with ground gradient
obstSpeedGain = np.array([6,4,-2,-6,-8])
thymio = rbt.RobotNav()
cap = cv2.VideoCapture(0)
img = vs.get_image(cap)
i = 0 #step vis graph
path = 0
while cap.isOpened():
    ret, frame = cap.read()
    
    if thymio.get_state() == 0:
        thymio.initialisation_step(frame, margin, True)
        thymio.set_state(1)
        path = thymio.get_path('real')
        print("fin state")
    if thymio.get_state() == 1:  #motion control commence
        pos_thy, two_centres, test_detect = vs.detect_start1(frame, False)  #recupere pos thymio, #test_detect bool a false si thymio pas detetc
        if test_detect:
            thymio.update_position_cam(two_centres, node, client)
        else:
            thymio.update_position_kalman(node, client, False)
        frame = glb.draw_path(frame, path) #dessine chemin du thymio new fenetre
        
        path_img = thymio.get_path('img')
        path_kalman = thymio.get_path('kalman')
        #print(path_img)
        if test_detect :  
            frame = glb.draw_thymio(frame, path_img)
        else:
            frame = glb.draw_thymio(frame, path_kalman)
        if len(path) > (i+1):
            next_goal = (path[i+1].x,path[i+1].y) 
            angle = get_angle2goal(thymio.get_geometry(), next_goal) 
            test_arr = ctrl.astolfi(pos_thy, angle, next_goal, node)
            if test_arr:
                i = i + 1
                if i == (len(path)):
                    thymio.set_state(2)
                    ctrl.stop_motors(node)
                    print("arrivee")
                    print(thymio.get_state())
                    break 
             #angle entre thymio et point
            #get_correct_orientation(angle, node, 20, 0.3)
            #if get_correct_orientation(angle, node, 20, 0.3):
            #    print("avance")
            #    get_distance(thymio.get_geometry()[0], next_goal, 30, 80, node)
            #if get_distance(thymio.get_geometry()[0], next_goal, 30, 80, node):
                
                
    
       
        
    cv2.imshow('frame',frame)     
    if cv2.waitKey(1) == ord('q'):
        ctrl.stop_motors(node)
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# [Point(118.00, 225.00), Point(290.64, 337.68), Point(401.67, 333.46), Point(511.00, 317.00)]
# <class 'numpy.ndarray'>
# la
# [[array([ 65.18206692, 252.83097284]), array([211.18246192, 299.19304671]), array([109.42525902, 349.94522988])], [array([283.89052475, 141.32702783]), array([389.95449077, 138.55856961]), array([401.67238864, 333.46160323]), array([290.64499396, 337.67839721])]]
# 65.18206692485906
# 252.83097283999984
# in
# in
# fin state
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25556/1284527851.py in <module>
#      18         pos_thy, two_centres, test_detect = vs.detect_start1(frame, False)  #recupere pos thymio, #test_detect bool a false si thymio pas detetc
#      19         if test_detect:
# ---> 20             thymio.update_position_cam(two_centres)
#      21         else:
#      22             thymio.update_position_kalman(node, client, False)
#
# TypeError: update_position_cam() missing 2 required positional arguments: 'node' and 'client'

# %%
cap.release()
